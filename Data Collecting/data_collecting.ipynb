# %%
#Gerekli kütüphaneler
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#Gerekli listeler
url_list = []
prices_list = []
propTitles = []
propValues = []
#Özelliklerin çekilmesi
for i in range(1,2): #2 yerine sayfa sayısı gelmeli
    url = "https://www.trendyol.com/cep-telefonu-x-c103498?pi=" + str(i) #Urlin for döngsü ile güncellenmesi
    r = requests.get(url) #Hazırlanan url'e istek yapılması
    source = BeautifulSoup(r.content,"lxml") #İstek yapılan sayfanın içeriğinin çekilmesi
    
    
    urls = source.find_all("div",attrs={"class":"p-card-chldrn-cntnr"}) #Tüm verilerin bulunması
    for url in urls:
        url_phone = "https://www.trendyol.com/"+url.a.get("href") #Verilerin linklerinin bulunması
        url_list.append(url_phone) #Linklerin kaydedilmesi
        print(url_phone)
        
        r_phone = requests.get(url_phone) #Bulunan linke tekrar istek atılması
        source_phone = BeautifulSoup(r_phone.content,"lxml") #Veri içeriğinin çekilmesi
        
        properties = source_phone.find_all("div",attrs={"class":"prop-item"}) #Bütün özelliklerin bulunması
        for prop in properties:
            prop_title = prop.find("div",attrs={"class":"item-key"}).text
            prop_value = prop.find("div",attrs={"class":"item-value"}).text
            propTitles.append(prop_title)
            propValues.append(prop_value)
        
        
    prices = source.find_all("div",attrs={"class":"prc-box-sllng"}) #Bütün fiyat özelliklerinin bulunması
    for price in prices:
        prices_list.append(price.text) #Bulunan özellikler arasında gezinme ve listeye yazma
        print(price.text)
    
    
        
    
print(str(len(url_list))+" Adet link bulundu.")
print(str(len(prices_list))+" Adet fiyat bulundu.")
print(str(len(propTitles))+" Adet özellik başlığı bulundu.")
print(str(len(propValues))+" Adet özellik verisi bulundu.")
# Out:
# https://www.trendyol.com//apple/iphone-11-64gb-beyaz-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-65149494
# https://www.trendyol.com//apple/iphone-11-64gb-siyah-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-64074791
# https://www.trendyol.com//xiaomi/redmi-note-9-pro-128gb-gri-cep-telefonu-xiaomi-turkiye-garantiili-p-40929877
# https://www.trendyol.com//xiaomi/poco-x3-nfc-128gb-siyah-cep-telefonu-xiaomi-turkiye-garantili-p-55239427
# https://www.trendyol.com//apple/iphone-se-2020-64-gb-beyaz-cep-telefonu-apple-turkiye-garantili-aksesuarli-kutu-p-40776212
# https://www.trendyol.com//samsung/galaxy-m51-cift-sim-128gb-siyah-samsung-turkiye-garantili-p-48505096
# https://www.trendyol.com//apple/iphone-11-128gb-beyaz-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-64074794
# https://www.trendyol.com//xiaomi/redmi-note-9-pro-128gb-yesil-cep-telefonu-xiaomi-turkiye-garantili-p-40928205
# https://www.trendyol.com//xiaomi/redmi-note-9-pro-128gb-beyaz-cep-telefonu-xiaomi-turkiye-garantiili-p-40929876
# https://www.trendyol.com//xiaomi/poco-x3-nfc-128gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-55384555
# https://www.trendyol.com//xiaomi/redmi-note-9-128gb-gri-cep-telefonu-xiaomi-turkiye-garantiili-p-41474951
# https://www.trendyol.com//xiaomi/redmi-note-8-64gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-31861679
# https://www.trendyol.com//samsung/galaxy-m51-cift-sim-128gb-beyaz-samsung-turkiye-garantili-p-48760291
# https://www.trendyol.com//samsung/galaxy-a31-128gb-cift-sim-prizma-mavi-cep-telefonu-samsung-turkiye-garantili-p-39296859
# https://www.trendyol.com//general-mobile/gm-20-64-gb-siyah-akilli-cep-telefonu-p-49276269
# https://www.trendyol.com//huawei/p40-lite-128gb-siyah-cep-telefonu-huawei-turkiye-garantili-p-39474847
# https://www.trendyol.com//samsung/galaxy-m31s-cift-sim-128gb-siyah-cep-telefonu-samsung-turkiye-garantili-p-51678102
# https://www.trendyol.com//samsung/galaxy-m21-64gb-cift-sim-siyah-cep-telefonu-samsung-turkiye-garantili-p-46468715
# https://www.trendyol.com//xiaomi/redmi-note-8-64gb-beyaz-cep-telefonu-xiaomi-turkiye-garantili-p-31861680
# https://www.trendyol.com//samsung/galaxy-a11-32gb-beyaz-cep-telefonu-samsung-turkiye-garantili-p-42332064
# https://www.trendyol.com//xiaomi/redmi-9c-64gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-52856177
# https://www.trendyol.com//xiaomi/redmi-note-8-64gb-siyah-cep-telefonu-xiaomi-turkiye-garantili-p-31883160
# https://www.trendyol.com//xiaomi/poco-x3-nfc-64gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-58947637
# https://www.trendyol.com//samsung/galaxy-a11-32gb-siyah-cep-telefonu-samsung-turkiye-garantili-p-42332060
# 7.484 TL
# 7.499 TL
# 3.189 TL
# 3.175 TL
# 4.689 TL
# 3.570 TL
# 8.099 TL
# 3.184 TL
# 3.245 TL
# 3.239 TL
# 2.710 TL
# 2.509 TL
# 3.566 TL
# 2.741 TL
# 1.658 TL
# 3.019 TL
# 2.989 TL
# 2.474 TL
# 2.515 TL
# 2.004 TL
# 1.989 TL
# 2.500 TL
# 2.929 TL
# 2.009 TL
# 24 Adet link bulundu.
# 24 Adet fiyat bulundu.
# 349 Adet özellik başlığı bulundu.
# 349 Adet özellik verisi bulundu.

# %%
#Url ve fiyatları bir data frame yazma
df_urls = pd.DataFrame()
df_urls["urls"] = url_list
df_urls["prices"] = prices_list

# %%
df_urls.head()
# Out:
#                                                 urls    prices
# 0  https://www.trendyol.com//apple/iphone-11-64gb...  7.484 TL
# 1  https://www.trendyol.com//apple/iphone-11-64gb...  7.499 TL
# 2  https://www.trendyol.com//xiaomi/redmi-note-9-...  3.189 TL
# 3  https://www.trendyol.com//xiaomi/poco-x3-nfc-1...  3.175 TL
# 4  https://www.trendyol.com//apple/iphone-se-2020...  4.689 TL

# %%
#Bulunan veri sayısı
phones = len(url_list)

# %%
#Bulunan özellik başlıklarının benzersizlerini bulma
columns = np.array(propTitles)
columns = np.unique(columns)

# %%
#Başlıkları kullanarak url ve fiyat ile birlikte yeni bir data frame oluşturma
df = pd.DataFrame(columns=columns)
df["url"] = url_list
df["price"] = prices_list

# %%
#Oluşturulan data frame gösterme
df.head()
# Out:
#   Ana Kamera Flaş: Ana Kamera Çözünürlül Aralığı: Arka Kamera Sayısı:  \
# 0              NaN                            NaN                 NaN
# 1              NaN                            NaN                 NaN
# 2              NaN                            NaN                 NaN
# 3              NaN                            NaN                 NaN
# 4              NaN                            NaN                 NaN
#
#   Batarya Kapasitesi Aralığı: Bağlantılar: Bluetooth: CPU Aralık:  \
# 0                         NaN          NaN        NaN         NaN
# 1                         NaN          NaN        NaN         NaN
# 2                         NaN          NaN        NaN         NaN
# 3                         NaN          NaN        NaN         NaN
# 4                         NaN          NaN        NaN         NaN
#
#   Cep Telefonu Modeli: Dahili Hafıza: Dokunmatik Ekran:  ... Ön Kamera Flaş:  \
# 0                  NaN            NaN               NaN  ...             NaN
# 1                  NaN            NaN               NaN  ...             NaN
# 2                  NaN            NaN               NaN  ...             NaN
# 3                  NaN            NaN               NaN  ...             NaN
# 4                  NaN            NaN               NaN  ...             NaN
#
#   Ön Kamera Sayısı: Ön Kamera Çözünürlük Aralığı: Ön Kamera Çözünürlüğü:  \
# 0               NaN                           NaN                    NaN
# 1               NaN                           NaN                    NaN
# 2               NaN                           NaN                    NaN
# 3               NaN                           NaN                    NaN
# 4               NaN                           NaN                    NaN
#
#   İşlemci Markası: İşletim Sistemi: Şarj Girişi: Şarj Hızı:  \
# 0              NaN              NaN          NaN        NaN
# 1              NaN              NaN          NaN        NaN
# 2              NaN              NaN          NaN        NaN
# 3              NaN              NaN          NaN        NaN
# 4              NaN              NaN          NaN        NaN
#
#                                                  url     price
# 0  https://www.trendyol.com//apple/iphone-11-64gb...  7.484 TL
# 1  https://www.trendyol.com//apple/iphone-11-64gb...  7.499 TL
# 2  https://www.trendyol.com//xiaomi/redmi-note-9-...  3.189 TL
# 3  https://www.trendyol.com//xiaomi/poco-x3-nfc-1...  3.175 TL
# 4  https://www.trendyol.com//apple/iphone-se-2020...  4.689 TL
#
# [5 rows x 45 columns]

# %%
#Data frame'i kullanarak bütün verileri çekme ve sütunlara yazdırma
for i in range(0,phones):
    url = df['url'].loc[i]
    r = requests.get(url)
    source = BeautifulSoup(r.content,"lxml")
    
    properties = source.find_all("div",attrs={"class":"prop-item"})
    for prop in properties:
        prop_title = prop.find("div",attrs={"class":"item-key"}).text
        prop_value = prop.find("div",attrs={"class":"item-value"}).text
        print(prop_title+prop_value)
        df[prop_title].loc[i] = prop_value
# Out:
# Dahili Hafıza:128 GB
# Garanti Tipi:Resmi Distribütör Garantili
# Renk:Gri
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:1.6 MP - 2 MP
# Cep Telefonu Modeli:Redmi Note 9 Pro
# Dahili Hafıza:64 GB
# Garanti Tipi:Apple Türkiye Garantili
# Renk:Beyaz
# Bağlantılar:Bluetooth
# Pil Gücü (mAh):1800 - 2400
# Ekran Boyutu:6 inç ve altı
# Kamera Çözünürlüğü:10 - 15 MP
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:5 - 8 MP
# Dahili Hafıza:128 GB
# Renk:Siyah
# Garanti Tipi:Samsung TR Garantili
# Bağlantılar:Bluetooth
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Dahili Hafıza:128 GB
# Renk:Yeşil
# Garanti Tipi:Xiaomi Türkiye Garantili
# Bağlantılar:USB
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Dahili Hafıza:128 GB
# Garanti Tipi:Resmi Distribütör Garantili
# Renk:Beyaz
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:1.6 MP - 2 MP
# Cep Telefonu Modeli:Redmi Note 9 Pro
# Dahili Hafıza:128 GB
# Garanti Tipi:Resmi Distribütör Garantili
# Renk:Gri
# Bağlantılar:Wi-Fi
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:2.1 MP - 12 MP
# Dahili Hafıza:64 GB
# Renk:Mavi
# Garanti Tipi:Xiaomi Türkiye Garantili
# Pil Gücü (mAh):3000 - 4000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:10 - 15 MP
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Dahili Hafıza:128 GB
# İşlemci Markası:Samsung
# Garanti Tipi:Samsung TR Garantili
# Bağlantılar:Bluetooth
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Ekran Boyut Aralığı:6.5'' - 7''
# Ekran Cinsi:Super AMOLED
# Ekran Teknolojisi:FHD+
# Ekran Boyutu Aralığı:6.5" - 7"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:4
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:20 - 40 MP
# Ön Kamera Flaş:Yok
# İşletim Sistemi:Android
# Renk:Beyaz
# RAM Kapasitesi:8 GB
# CPU Aralık:2.0-2.5 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:6000-7000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:20-40 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Yok
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Yok
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı:80 - 100 MP
# Garanti Tipi:Resmi Distribütör Garantili
# Dahili Hafıza:128 GB
# İşletim Sistemi:Android
# Bağlantılar:3.5 mm Jack
# Pil Gücü (mAh):4000 - 5000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Cep Telefonu Modeli:Galaxy A31
# Ekran Boyut Aralığı:6.5'' - 7''
# Ekran Cinsi:Super AMOLED
# Ekran Teknolojisi:FHD+
# Ekran Boyutu Aralığı:6.5" - 7"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:4
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:20 - 40 MP
# Ön Kamera Flaş:Yok
# Renk:Mavi
# İşlemci Markası:Samsung
# RAM Kapasitesi:4 GB
# CPU Aralık:1.5-2.0 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:4500-5000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:10-20 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Var
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Var
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:1080p (Full HD)
# Ana Kamera Çözünürlül Aralığı:40 - 60 MP
# Dahili Hafıza:128 GB
# İşletim Sistemi:Android
# Garanti Tipi:Samsung TR Garantili
# Bağlantılar:Bluetooth
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Cep Telefonu Modeli:Galaxy M31s
# Ekran Boyut Aralığı:6.5'' - 7''
# Ekran Cinsi:Super AMOLED
# Ekran Teknolojisi:FHD+
# Ekran Boyutu Aralığı:6"-6.5"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:4
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:20 - 40 MP
# Ön Kamera Flaş:Yok
# Renk:Siyah
# İşlemci Markası:Samsung
# RAM Kapasitesi:6 GB
# CPU Aralık:2.0-2.5 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:5000-6000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:20-40 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4.5G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Yok
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Var
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı:80 - 100 MP
# Dahili Hafıza:64 GB
# İşlemci Markası:Samsung
# Garanti Tipi:Samsung TR Garantili
# Bağlantılar:Bluetooth
# Pil Gücü (mAh):5000 ve üstü
# Ekran Boyutu:6 inch ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:AMOLED
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Ekran Boyut Aralığı:6'' - 6.5''
# Ekran Cinsi:Super AMOLED
# Ekran Teknolojisi:FHD+
# Ekran Boyutu Aralığı:6"-6.5"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:3
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:20 - 40 MP
# Ön Kamera Flaş:Yok
# İşletim Sistemi:Android
# Renk:Siyah
# RAM Kapasitesi:4 GB
# CPU Aralık:2.0-2.5 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:5000-6000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:10-20 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4.5G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Var
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Var
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı:40 - 60 MP
# Dahili Hafıza:64 GB
# Renk:Beyaz
# Garanti Tipi:Xiaomi Türkiye Garantili
# Pil Gücü (mAh):3000 - 4000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:10 - 15 MP
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Garanti Tipi:Resmi Distribütör Garantili
# Dahili Hafıza:32 GB
# İşletim Sistemi:Android
# Bağlantılar:3.5 mm Jack
# Pil Gücü (mAh):3000 - 4000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:15 - 20 MP
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:5 - 8 MP
# Cep Telefonu Modeli:Galaxy A11
# Ekran Boyut Aralığı:6'' - 6.5''
# Ekran Cinsi:PLS
# Ekran Teknolojisi:HD
# Ekran Boyutu Aralığı:6"-6.5"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:3
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:5 - 10 MP
# Ön Kamera Flaş:Yok
# Renk:Beyaz
# İşlemci Markası:Samsung
# RAM Kapasitesi:2 GB
# CPU Aralık:1.5-2.0 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:3500-4000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:10-20 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4.5G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Var
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Var
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:1080p (Full HD)
# Ana Kamera Çözünürlül Aralığı:15 - 20 MP
# Dahili Hafıza:64 GB
# Renk:Siyah
# Garanti Tipi:Xiaomi Türkiye Garantili
# Pil Gücü (mAh):3000 - 4000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:10 - 15 MP
# Ekran Çözünürlüğü:FHD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Dahili Hafıza:64 GB
# Renk:Mavi
# Garanti Tipi:Xiaomi Türkiye Garantili
# Pil Gücü (mAh):5000 ve üstü
# Kamera Çözünürlüğü:20 MP ve üstü
# Ön Kamera Çözünürlüğü:8 MP ve üstü
# Garanti Tipi:Resmi Distribütör Garantili
# Dahili Hafıza:32 GB
# İşletim Sistemi:Android
# Bağlantılar:3.5 mm Jack
# Pil Gücü (mAh):3000 - 4000
# Ekran Boyutu:6 inç ve üstü
# Kamera Çözünürlüğü:15 - 20 MP
# Ekran Çözünürlüğü:HD+
# Görüntü Teknolojisi:LCD
# Ön Kamera Çözünürlüğü:5 - 8 MP
# Cep Telefonu Modeli:Galaxy A11
# Ekran Boyut Aralığı:6'' - 6.5''
# Ekran Cinsi:PLS
# Ekran Teknolojisi:HD
# Ekran Boyutu Aralığı:6"-6.5"
# Dokunmatik Ekran:Var
# Arka Kamera Sayısı:3
# Ana Kamera Flaş:Var
# Ön Kamera Sayısı:1
# Ön Kamera Çözünürlük Aralığı:5 - 10 MP
# Ön Kamera Flaş:Yok
# Renk:Siyah
# İşlemci Markası:Samsung
# RAM Kapasitesi:2 GB
# CPU Aralık:1.5-2.0 GHz
# Kulaklık Girişi:3.5 mm
# Batarya Kapasitesi Aralığı:3500-4000 mAh
# Şarj Girişi:USB Type-C
# Şarj Hızı:10-20 W
# Kablosuz Şarj:Yok
# Mobil Bağlantı Hızı:4.5G
# Bluetooth:Var
# GPS:Var
# NFC:Var
# Radio:Var
# Parmak İzi Okuyucu:Var
# Yüz Tanıma:Var
# Görüntülü Konuşma:Var
# Suya/Toza Dayanıklılık:Yok
# Çift Hat:Var
# Ekran Yenileme Hızı:60 Hz
# Video Kayıt Çözünürlüğü:1080p (Full HD)
# Ana Kamera Çözünürlül Aralığı:15 - 20 MP

# %%
df.head()
# Out:
#   Ana Kamera Flaş: Ana Kamera Çözünürlül Aralığı: Arka Kamera Sayısı:  \
# 0              NaN                            NaN                 NaN
# 1              NaN                            NaN                 NaN
# 2              NaN                            NaN                 NaN
# 3              NaN                            NaN                 NaN
# 4              NaN                            NaN                 NaN
#
#   Batarya Kapasitesi Aralığı: Bağlantılar: Bluetooth: CPU Aralık:  \
# 0                         NaN          NaN        NaN         NaN
# 1                         NaN          NaN        NaN         NaN
# 2                         NaN          NaN        NaN         NaN
# 3                         NaN          NaN        NaN         NaN
# 4                         NaN    Bluetooth        NaN         NaN
#
#   Cep Telefonu Modeli: Dahili Hafıza: Dokunmatik Ekran:  ... Ön Kamera Flaş:  \
# 0                  NaN            NaN               NaN  ...             NaN
# 1                  NaN            NaN               NaN  ...             NaN
# 2     Redmi Note 9 Pro         128 GB               NaN  ...             NaN
# 3                  NaN            NaN               NaN  ...             NaN
# 4                  NaN          64 GB               NaN  ...             NaN
#
#   Ön Kamera Sayısı: Ön Kamera Çözünürlük Aralığı: Ön Kamera Çözünürlüğü:  \
# 0               NaN                           NaN                    NaN
# 1               NaN                           NaN                    NaN
# 2               NaN                           NaN          1.6 MP - 2 MP
# 3               NaN                           NaN                    NaN
# 4               NaN                           NaN               5 - 8 MP
#
#   İşlemci Markası: İşletim Sistemi: Şarj Girişi: Şarj Hızı:  \
# 0              NaN              NaN          NaN        NaN
# 1              NaN              NaN          NaN        NaN
# 2              NaN              NaN          NaN        NaN
# 3              NaN              NaN          NaN        NaN
# 4              NaN              NaN          NaN        NaN
#
#                                                  url     price
# 0  https://www.trendyol.com//apple/iphone-11-64gb...  7.484 TL
# 1  https://www.trendyol.com//apple/iphone-11-64gb...  7.499 TL
# 2  https://www.trendyol.com//xiaomi/redmi-note-9-...  3.189 TL
# 3  https://www.trendyol.com//xiaomi/poco-x3-nfc-1...  3.175 TL
# 4  https://www.trendyol.com//apple/iphone-se-2020...  4.689 TL
#
# [5 rows x 45 columns]

# %%
#Data frame'i csv formatına çevirip kaydetme
df.to_csv("phone_trendyol_data.csv",index=False)

# %%
df.columns
# Out:
# Index(['Ana Kamera Flaş:', 'Ana Kamera Çözünürlül Aralığı:',
#        'Arka Kamera Sayısı:', 'Batarya Kapasitesi Aralığı:', 'Bağlantılar:',
#        'Bluetooth:', 'CPU Aralık:', 'Cep Telefonu Modeli:', 'Dahili Hafıza:',
#        'Dokunmatik Ekran:', 'Ekran Boyut Aralığı:', 'Ekran Boyutu Aralığı:',
#        'Ekran Boyutu:', 'Ekran Cinsi:', 'Ekran Teknolojisi:',
#        'Ekran Yenileme Hızı:', 'Ekran Çözünürlüğü:', 'GPS:', 'Garanti Tipi:',
#        'Görüntü Teknolojisi:', 'Görüntülü Konuşma:', 'Kablosuz Şarj:',
#        'Kamera Çözünürlüğü:', 'Kulaklık Girişi:', 'Mobil Bağlantı Hızı:',
#        'NFC:', 'Parmak İzi Okuyucu:', 'Pil Gücü (mAh):', 'RAM Kapasitesi:',
#        'Radio:', 'Renk:', 'Suya/Toza Dayanıklılık:',
#        'Video Kayıt Çözünürlüğü:', 'Yüz Tanıma:', 'Çift Hat:',
#        'Ön Kamera Flaş:', 'Ön Kamera Sayısı:', 'Ön Kamera Çözünürlük Aralığı:',
#        'Ön Kamera Çözünürlüğü:', 'İşlemci Markası:', 'İşletim Sistemi:',
#        'Şarj Girişi:', 'Şarj Hızı:', 'url', 'price'],
#       dtype='object')
